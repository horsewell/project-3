# %%
# Dependencies
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import time

# %%
start = datetime.datetime(2014,3,5)
end = datetime.datetime(2024,3,4)

# %%
# Create a path variable to the data.
stock_data = Path('Resources/clean-HisotricalData.csv')

# %%
# The correct encoding must be used to read the CSV in pandas
stock_data_df = pd.read_csv(stock_data)

# %%
# Preview of the DataFrame
stock_data_df.head()
# Out:
#    Unnamed: 0        Date   Close    Volume     Open     High     Low  \
# 0           1   4/03/2024  177.58  37381520  177.530  180.140  177.49
# 1           2   1/03/2024  178.22  31981150  176.750  178.725  176.07
# 2           3  29/02/2024  176.76  53805360  173.010  177.220  172.85
# 3           4  28/02/2024  173.16  28180480  172.440  174.050  172.27
# 4           5  27/02/2024  173.54  31141730  174.075  174.620  172.86
#
#   StockCode
# 0      AMZN
# 1      AMZN
# 2      AMZN
# 3      AMZN
# 4      AMZN

# %%
stockcodes = stock_data_df['StockCode'].tolist()
#stockcodes.head()
# Out:
# 0    AMZN
# 1    AMZN
# 2    AMZN
# 3    AMZN
# 4    AMZN
# Name: StockCode, dtype: object

# %%
# create empty dataframe
stock_final = pd.DataFrame()
# iterate over each symbol
for i in stockcodes:  
    
    # print the stockcode
    print( str(stockcodes.index(i)) + str(' : ') + i, sep=',', end=',', flush=True)  
    
    try:
        # download the stock price 
        stock = []
        stock = yf.download(i,start=start, end=end, progress=False)
        
        # append the individual stock prices 
        if len(stock) == 0:
            None
        else:
            stock['Name']=i
            stock_final = stock_final.append(stock,sort=False)
    except Exception:
        None

# %%
# Set the ticker list
tickers_list = ['AMZN', 'APPL', 'META', 'NFLX']

# %%
# Create placeholder for data
data = pd.DataFrame(columns=tickers_list)
data.head()
# Out:
# Empty DataFrame
# Columns: [AMZN, APPL, META, NFLX]
# Index: []

# %%
# Fetch the data
for ticker in tickers_list:
    data[ticker] = (ticker, 
                               start,
                               end)['Close']
# Out:
# <>:3: SyntaxWarning: tuple indices must be integers or slices, not str; perhaps you missed a comma?
# <>:3: SyntaxWarning: tuple indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\CONTRA~1\AppData\Local\Temp/ipykernel_13240/443242362.py:3: SyntaxWarning: tuple indices must be integers or slices, not str; perhaps you missed a comma?
#   data[ticker] = (ticker,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\CONTRA~1\AppData\Local\Temp/ipykernel_13240/443242362.py in <module>
#       1 # Fetch the data
#       2 for ticker in tickers_list:
# ----> 3     data[ticker] = (ticker,
#       4                                start,
#       5                                end)['Close']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# Set the ticker APPL
ticker_APPL = 'APPL'

data_APPL = yf.download(ticker_APPL, start, end)

data_APPL['Close'].plot()
plt.show()

# %%
# Set the ticker META
ticker_META = 'META'

data_META = yf.download(ticker_META, start, end)

data_META['Close'].plot()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Set the ticker NFLX
ticker_NFLX = 'NFLX'

data_NFLX = yf.download(ticker_NFLX, start, end)

data_NFLX['Close'].plot()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Plot the adjusted close price
data_AMZN['Close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Close Price of %s" % ticker_AMZN, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()

# %%
# Visualizing Stock Price Movements
plt.style.use('seaborn')

plt.figure(figsize=(16,10))
plt.plot(stock_data_df['Close'],'-')
plt.gcf().autofmt_xdate()
plt.title('MANA Stock Price 2014-2024', fontsize=16)
plt.xlabel('Date',fontsize=16)
plt.ylabel('$', fontsize=16)
plt.show()

# %%
stockcodes = stock_data_df['StockCode'].tolist() 
#stockcodes.head()

# %%
# create empty dataframe
stock_final = pd.DataFrame()
# iterate over each symbol
for i in stockcodes:  
    
    # print the symbol which is being downloaded
    print( str(stockcodes.index(i)) + str(' : ') + i, sep=',', end=',', flush=True)  
    
    try:
        # download the stock price 
        stock = []
        stock = yf.download(i,start=start, end=end, progress=False)
        
        # append the individual stock prices 
        if len(stock) == 0:
            None
        else:
            stock['Name']=i
            stock_final = stock_final.append(stock,sort=False)
    except Exception:
        None
# Out:
# 0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN,0 : AMZN
# ...

# %%
stock_final.head()
# Out:
#                  Open       High      Low      Close  Adj Close    Volume  \
# Date
# 2014-03-05  18.206499  18.636499  18.1950  18.618500  18.618500  76966000
# 2014-03-06  18.702499  18.766500  18.4450  18.608000  18.608000  58532000
# 2014-03-07  18.729000  18.749500  18.4765  18.603001  18.603001  45596000
# 2014-03-10  18.634501  18.636499  18.3500  18.526501  18.526501  42116000
# 2014-03-11  18.549500  18.639999  18.3640  18.441000  18.441000  44922000
#
#             Name
# Date
# 2014-03-05  AMZN
# 2014-03-06  AMZN
# 2014-03-07  AMZN
# 2014-03-10  AMZN
# 2014-03-11  AMZN

# %%
tickers_data = []
tickers_prices = {}
tickers_df = {}


for ticker in tickers:
    try:
        raw_data = pdr.get_data_yahoo(ticker, start="2013-01-01", end="2023-04-30")[['Adj Close']].rename(columns={'Adj Close': 'Price'}).copy()
        raw_data['d+1'] = raw_data['Price'].shift(-1)
        raw_data['ROI'] = np.log(raw_data['d+1'] / raw_data['Price']) * 100
        monthly_price = raw_data.resample('M').last()
        monthly_price['lower'] = monthly_price['ROI'] - monthly_price['ROI'].std()
        monthly_price['upper'] = monthly_price['ROI'] + monthly_price['ROI'].std()
        
        tickers_prices[ticker] = {
            'Expected Return': monthly_price['ROI'].mean(),
            'Risk': monthly_price['ROI'].std(),
            'Data_length': len(monthly_price['ROI']),
            'Data': {
                'Changes': monthly_price['ROI'].values.tolist(),
                'Margin of Error': monthly_price[['lower', 'upper']].values.tolist()
            }
        }
        tickers_data.append([ticker, monthly_price['ROI'].mean(), monthly_price['ROI'].std(), len(monthly_price['ROI'])])
        tickers_df[ticker] = monthly_price
    except Exception as e:
        print(e)
        print(ticker)
